# %% [markdown]
# ## This exercise is the first hands-on attempt to use Qiskit API to perform quantum computing in this class.
# ### The points you get in this exercise will be the additional points for your final score.
# ### Please anwer each question with code and dicusssion in this jupyter notebook. After completion, upload to Moodle by 18:00 today.

# %% [markdown]
# 1. [4pts] Create a circuit and show superposition of one qubit.
#  How is the measurement probability different on IBMQ machine and simulator?

# %% [markdown]
#  2.  [8pts]Create a circuit and show entanglement between two qubits. What is the measurement probability you expect? Explain your expectation. How is the measurement probability different on IBMQ machine and simulator?

# %% [markdown]
# 3. [8pts] Backward sign propagation. Create a circuit of two qubits and prepare the initial state as $|+\rangle|-\rangle$. Apply a cnot gate to achieve the backward sign propagation. How to observe the backward sign propagation? Hint: a. using statevector simulator. b. apply H again in the end of circuit, then perform measurement.
